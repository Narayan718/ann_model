# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import missingno as msno

# %%
data = pd.read_csv('loan_data.csv')
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
data.shape
# Out:
# (614, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
msno.bar(data)
plt.title('Checking for the null values', size=16)
plt.show()

# %%
data.nunique()
# Out:
# Loan_ID              614
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           203
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
#imputing the nan values in categorical variables with mode of the column.
data['Gender'].fillna(data['Gender'].mode()[0], inplace=True)
data['Married'].fillna(data['Married'].mode()[0], inplace=True)
data['Dependents'].fillna(data['Dependents'].mode()[0], inplace=True)
data['Self_Employed'].fillna(data['Self_Employed'].mode()[0], inplace=True)
data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].mode()[0], inplace=True)
data['Credit_History'].fillna(data['Credit_History'].mode()[0], inplace=True)

# %%
#imputing the nan values in numerical variable with mean of the column.
data['LoanAmount'].fillna(data['LoanAmount'].mean(), inplace=True)

# %%
#visualization of NaN values
plt.figure(figsize=(12,5))
sns.heatmap(data.isnull(), yticklabels=False)
plt.title('Checking for the null values', size=16)
plt.xlabel('Features', size=14)
plt.show()

# %%
#converting the categorical variables to system readle numerical values
data['Gender'] = data['Gender'].map({'Male': 0, 'Female': 1})
data['Married'] = data['Married'].map({'No': 0, 'Yes': 1})
data['Dependents'] = data['Dependents'].map({'0': 0, '1': 1, '2': 2, '3+': 3})
data['Education'] = data['Education'].map({'Graduate': 1, 'Not Graduate': 0})
data['Self_Employed'] = data['Self_Employed'].map({'No': 0, 'Yes': 1})
data['Property_Area'] = data['Property_Area'].map({'Rural': 0, 'Semiurban': 1, 'Urban': 2})
data['Loan_Status'] = data['Loan_Status'].map({'N': 0, 'Y': 1})

# %%
#visualization of distribution of whole data in histogram
data.hist(figsize=(20, 10))
plt.show()

# %%
parameters = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 
              'Credit_History', 'Property_Area', 'Loan_Status']

#visualization of the value counts
for col in parameters:
    fig = plt.figure(figsize=(12, 5))
    ax = fig.gca()
    ch = sns.countplot(x=col, data=data, ax=ax)
    plt.xlabel(col, size=14)
    plt.ylabel('Count', size=14)
    plt.title(f"Value counts of {col}", size=16)
    for p in ch.patches:
        ch.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), ha='center', va='top', size=16)
    plt.show()

# %%
plt.figure(figsize=(12, 5))
sns.countplot(data['Loan_Amount_Term'])
plt.xlabel('Loan Amount Term', size=14)
plt.ylabel('Counts', size=14)
plt.title('Value counts of Loan_Amount_Term', size=16)
plt.show()

# %%
plt.figure(figsize=(12,5))
ch = sns.countplot(x='Gender', hue='Education', data=data)
plt.title('Gender Vs Education', size=16)
plt.xlabel('Gender and Education', size=14)
plt.ylabel("Count", size=14)
for p in ch.patches:
    ch.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), ha='center', va='top', size=14)
plt.show()

# %%
plt.figure(figsize=(12,5))
ch = sns.countplot(x='Gender', hue='Self_Employed', data=data)
plt.title('Gender Vs Self Employed', size=16)
plt.xlabel('Gender and Self Employed', size=14)
plt.ylabel("Count", size=14)
for p in ch.patches:
    ch.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), ha='center', va='top', size=14)
plt.show()

# %%
plt.figure(figsize=(12,5))
ch = sns.countplot(x='Education', hue='Self_Employed', data=data)
plt.title('Education Vs Self Employed', size=16)
plt.xlabel('Education and Self Employed', size=14)
plt.ylabel("Count", size=14)
for p in ch.patches:
    ch.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), ha='center', va='top', size=14)
plt.show()

# %%
parameters = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Credit_History', 'Property_Area']

for col in parameters:
    fig = plt.figure(figsize=(12,5))
    ax = fig.gca()
    ch = sns.countplot(x=col, hue='Loan_Status', data=data)
    plt.title(f"Distibution of {col} on the basis of Loan Status", size=16)
    plt.xlabel(f'{col} and Loan status', size=14)
    plt.ylabel("count", size=14)
    for p in ch.patches:
        ch.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), ha='center', va='top', size=14)
    plt.show()

# %%
#visualization of the correlation in the heatmap
plt.figure(figsize=(15, 7))
sns.heatmap(data.corr(), annot=True)
plt.title('Correlation between all the vaibles', size=16)
plt.show()

# %%
data.drop(['Loan_ID'], axis=1, inplace=True)

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify = data['Loan_Status'], random_state=10)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import InputLayer, Dense

# %%
#defining the hidden layers and neurons ineach layer
input_layers = X_train.shape[1]
output_layers = 1
number_of_hidden_layers = 2
neuron_hidden_layer1 = 10
neuron_hidden_layer2 = 5

# %%
model = Sequential()
model.add(InputLayer(input_shape=(input_layers,)))
model.add(Dense(units=neuron_hidden_layer1, activation='relu'))
model.add(Dense(units=neuron_hidden_layer2, activation='relu'))
model.add(Dense(units=output_layers, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                120
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
model_history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 3s 31ms/step - loss: 0.7174 - accuracy: 0.4399 - val_loss: 0.7024 - val_accuracy: 0.4553
# Epoch 2/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.6935 - accuracy: 0.4929 - val_loss: 0.6825 - val_accuracy: 0.5610
# Epoch 3/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6742 - accuracy: 0.5499 - val_loss: 0.6680 - val_accuracy: 0.6504
# Epoch 4/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6586 - accuracy: 0.6354 - val_loss: 0.6572 - val_accuracy: 0.6748
# Epoch 5/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6462 - accuracy: 0.6925 - val_loss: 0.6483 - val_accuracy: 0.6992
# Epoch 6/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6353 - accuracy: 0.7149 - val_loss: 0.6406 - val_accuracy: 0.7317
# Epoch 7/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6258 - accuracy: 0.7352 - val_loss: 0.6336 - val_accuracy: 0.7480
# Epoch 8/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6161 - accuracy: 0.7413 - val_loss: 0.6263 - val_accuracy: 0.7561
# Epoch 9/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.6061 - accuracy: 0.7617 - val_loss: 0.6192 - val_accuracy: 0.7398
# Epoch 10/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5966 - accuracy: 0.7719 - val_loss: 0.6121 - val_accuracy: 0.7480
# Epoch 11/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5875 - accuracy: 0.7780 - val_loss: 0.6058 - val_accuracy: 0.7724
# Epoch 12/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5776 - accuracy: 0.7902 - val_loss: 0.5988 - val_accuracy: 0.7886
# Epoch 13/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5684 - accuracy: 0.7943 - val_loss: 0.5920 - val_accuracy: 0.7967
# Epoch 14/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5592 - accuracy: 0.7984 - val_loss: 0.5863 - val_accuracy: 0.7967
# Epoch 15/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5504 - accuracy: 0.7984 - val_loss: 0.5807 - val_accuracy: 0.7967
# Epoch 16/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5423 - accuracy: 0.8045 - val_loss: 0.5747 - val_accuracy: 0.7967
# Epoch 17/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5344 - accuracy: 0.8065 - val_loss: 0.5685 - val_accuracy: 0.7967
# Epoch 18/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5271 - accuracy: 0.8065 - val_loss: 0.5623 - val_accuracy: 0.7967
# Epoch 19/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5192 - accuracy: 0.8065 - val_loss: 0.5557 - val_accuracy: 0.7967
# Epoch 20/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5119 - accuracy: 0.8065 - val_loss: 0.5488 - val_accuracy: 0.8049
# Epoch 21/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5042 - accuracy: 0.8106 - val_loss: 0.5429 - val_accuracy: 0.8049
# Epoch 22/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4981 - accuracy: 0.8106 - val_loss: 0.5365 - val_accuracy: 0.8049
# Epoch 23/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4925 - accuracy: 0.8126 - val_loss: 0.5316 - val_accuracy: 0.8049
# Epoch 24/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4878 - accuracy: 0.8126 - val_loss: 0.5277 - val_accuracy: 0.8049
# Epoch 25/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4833 - accuracy: 0.8126 - val_loss: 0.5233 - val_accuracy: 0.8049
# Epoch 26/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4801 - accuracy: 0.8126 - val_loss: 0.5206 - val_accuracy: 0.8049
# Epoch 27/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4768 - accuracy: 0.8126 - val_loss: 0.5187 - val_accuracy: 0.8049
# Epoch 28/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4742 - accuracy: 0.8126 - val_loss: 0.5169 - val_accuracy: 0.8049
# Epoch 29/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4716 - accuracy: 0.8126 - val_loss: 0.5159 - val_accuracy: 0.8049
# Epoch 30/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4693 - accuracy: 0.8126 - val_loss: 0.5145 - val_accuracy: 0.8049
# Epoch 31/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4669 - accuracy: 0.8147 - val_loss: 0.5126 - val_accuracy: 0.8049
# Epoch 32/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4650 - accuracy: 0.8147 - val_loss: 0.5112 - val_accuracy: 0.8049
# Epoch 33/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4634 - accuracy: 0.8147 - val_loss: 0.5104 - val_accuracy: 0.8049
# Epoch 34/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4621 - accuracy: 0.8147 - val_loss: 0.5096 - val_accuracy: 0.8049
# Epoch 35/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4601 - accuracy: 0.8147 - val_loss: 0.5101 - val_accuracy: 0.8049
# Epoch 36/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4582 - accuracy: 0.8147 - val_loss: 0.5084 - val_accuracy: 0.8049
# Epoch 37/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4567 - accuracy: 0.8147 - val_loss: 0.5071 - val_accuracy: 0.8049
# Epoch 38/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4556 - accuracy: 0.8126 - val_loss: 0.5067 - val_accuracy: 0.8049
# Epoch 39/50
# 16/16 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.90 - 0s 3ms/step - loss: 0.4540 - accuracy: 0.8147 - val_loss: 0.5066 - val_accuracy: 0.8049
# Epoch 40/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4527 - accuracy: 0.8147 - val_loss: 0.5074 - val_accuracy: 0.8049
# Epoch 41/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4516 - accuracy: 0.8167 - val_loss: 0.5068 - val_accuracy: 0.8049
# Epoch 42/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4506 - accuracy: 0.8147 - val_loss: 0.5063 - val_accuracy: 0.7886
# Epoch 43/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4492 - accuracy: 0.8167 - val_loss: 0.5061 - val_accuracy: 0.7886
# Epoch 44/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4483 - accuracy: 0.8167 - val_loss: 0.5058 - val_accuracy: 0.7886
# Epoch 45/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4474 - accuracy: 0.8147 - val_loss: 0.5057 - val_accuracy: 0.7886
# Epoch 46/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4462 - accuracy: 0.8147 - val_loss: 0.5062 - val_accuracy: 0.7886
# Epoch 47/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4454 - accuracy: 0.8147 - val_loss: 0.5056 - val_accuracy: 0.7886
# Epoch 48/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4443 - accuracy: 0.8147 - val_loss: 0.5056 - val_accuracy: 0.7886
# Epoch 49/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4436 - accuracy: 0.8147 - val_loss: 0.5055 - val_accuracy: 0.7886
# Epoch 50/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4427 - accuracy: 0.8147 - val_loss: 0.5056 - val_accuracy: 0.7886

# %%
pred_test = model.predict_classes(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4172/1533317154.py in <module>
# ----> 1 pred_test = model.predict_classes(X_test)
#
# AttributeError: 'Sequential' object has no attribute 'predict_classes'

# %%
accuracy_score(y_test, pred_test)

# %%
plt.figure(figsize=(12, 5))
plt.plot(model_history.history['loss'], label='train')
plt.plot(model_history.history['val_loss'], label='validation')
plt.title('Model Loss', size=16)
plt.xlabel('Epochs', size=14)
plt.ylabel('Loss', size=14)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.plot(model_history.history['accuracy'], label='train')
plt.plot(model_history.history['val_accuracy'], label='validation')
plt.title('Model accuracy', size=16)
plt.xlabel('Epochs', size=14)
plt.ylabel('Accuracy', size=14)
plt.legend()
plt.show()
